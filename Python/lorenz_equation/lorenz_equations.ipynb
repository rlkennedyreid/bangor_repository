# %%
import pandas
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_directory = 'C:/Users/rbk20xqk/Documents/google_backup/data/lorenz_equation/'
lorenz_data = pandas.read_csv(data_directory + "lorenz_sequence.csv", header=None)

# %%
lorenz_data
# Out:
#                0         1          2         3
# 0       0.000000  10.00000   1.000000   1.00000
# 1       0.007710   9.40816   2.997190   1.12779
# 2       0.017539   8.92164   5.356840   1.46991
# 3       0.028574   8.68193   7.826710   2.05762
# 4       0.040814   8.73730  10.427200   2.94783
# ...          ...       ...        ...       ...
# 4359   99.949800 -13.22870  -4.072870  40.93180
# 4360   99.964100 -11.85590  -1.805160  39.91880
# 4361   99.978300 -10.39610  -0.007107  38.56980
# 4362   99.992500  -8.92288   1.333910  37.04170
# 4363  100.000000  -8.16236   1.874000  36.20730
#
# [4364 rows x 4 columns]

# %%
plt.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

# Prepare arrays x, y, z
#theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
#z = np.linspace(-2, 2, 100)
#r = z**2 + 1
#x = r * np.sin(theta)
#y = r * np.cos(theta)

plt.plot(lorenz_data[1], lorenz_data[2], lorenz_data[3], linewidth=0.3)

plt.savefig(data_directory + "lorenz_attractor.png", format = 'png')
