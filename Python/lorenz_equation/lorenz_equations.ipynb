# %%
import pandas
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
data_directory = 'C:/Users/rbk20xqk/Documents/google_backup/data/lorenz_equation/'
lorenz_data = pandas.read_csv(data_directory + "lorenz_sequence.csv", header=None)

# %%
lorenz_data
# Out:
#                0         1         2         3
# 0       0.000000  10.00000   1.00000   1.00000
# 1       0.010000   9.26946   3.56370   1.19088
# 2       0.020000   8.84191   5.92145   1.58313
# 3       0.031319   8.66686   8.41990   2.23531
# 4       0.043850   8.79733  11.05790   3.20885
# ...          ...       ...       ...       ...
# 4438   99.929300  10.67070  14.30340  24.88720
# 4439   99.954600  11.51530  14.48960  27.19010
# 4440   99.975800  12.05610  14.13570  29.18630
# 4441   99.997700  12.38370  13.25150  31.10850
# 4442  100.000000  12.40180  13.13140  31.29090
#
# [4443 rows x 4 columns]

# %%
plt.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(15,10))
ax = fig.gca(projection='3d')

plt.plot(lorenz_data[1], lorenz_data[2], lorenz_data[3], linewidth=0.3)

plt.savefig(data_directory + "lorenz_attractor.png", format = 'png')

# %%
bifurcation_data = pandas.read_csv(data_directory + "lorenz_bifurcation.csv", header=None)

# %%
bifurcation_data
# Out:
#           0    1          2           3           4
# 0       0.0    1  -0.039630   -0.039628    0.000589
# 1       0.5    1  -0.039619   -0.039617    0.000589
# 2       1.0    1  -0.039609   -0.039607    0.000589
# 3       1.5    1  -0.039598   -0.039596    0.000588
# 4       2.0    1  -0.039587   -0.039585    0.000588
# ...     ...  ...        ...         ...         ...
# 39995  47.5  400  35.812900  -54.768500  435.226000
# 39996  48.0  400 -49.796100 -102.831000  443.789000
# 39997  48.5  400  19.680700   75.463600  326.453000
# 39998  49.0  400   1.375550  -48.232000  341.127000
# 39999  49.5  400 -33.048800   57.800000  425.825000
#
# [40000 rows x 5 columns]

# %%
plt.rcParams['legend.fontsize'] = 10

fig = plt.figure(figsize=(15,10))

plt.scatter(bifurcation_data[1], bifurcation_data[2], marker='.', s=0.5)

plt.savefig(data_directory + "lorenz_bifurcation.png", format = 'png')
