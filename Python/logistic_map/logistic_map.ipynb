# %%
import pandas
import matplotlib.pyplot as plt

# %%
data = pandas.read_csv("C:/Users/rbk20xqk/Documents/google_backup/data/logistic_map/bifurcation.csv", header=None)

# %%
fig = plt.figure(figsize=(15,10))
plt.xlim(0.0, 4.0)
plt.scatter(data[0], data[2], marker='.', s=1.5)
