# %%
import pandas
import matplotlib.pyplot as plt

# %%
bifurcation_data = pandas.read_csv("C:/Users/rbk20xqk/Documents/google_backup/data/logistic_map/bifurcation.csv", header=None)
lyapunov_data = pandas.read_csv("C:/Users/rbk20xqk/Documents/google_backup/data/logistic_map/lyapunov.csv", header=None)

# %%
plt.xlim(0.0, 4.0)
plt.scatter(bifurcation_data[0], bifurcation_data[2], marker='.', s=0.2)
plt.show()

# %%
plt.xlim(0.0, 4.0)
plt.ylim(-1.0)
plt.axhline(0.0, linewidth = 0.8, color = 'r')
plt.plot(lyapunov_data[0], lyapunov_data[1], linewidth=0.5)
plt.show()
